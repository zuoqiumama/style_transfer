# %%
import os
import glob
mode = 'train'
root = './datasets'
datasets_name = 'monet2photo'
'%s/A' % mode
# Out:
# 'train/A'

# %%
path_A = os.path.join(root, datasets_name, mode + 'A') + '/*.*'
path_A
# Out:
# './datasets\\monet2photo\\trainA/*.*'

# %%
#获取匹配路径名的所有文件
glob.glob(path_A)
# Out:
# ['./datasets\\monet2photo\\trainA\\00001.jpg',
#  './datasets\\monet2photo\\trainA\\00003.jpg',
#  './datasets\\monet2photo\\trainA\\00004.jpg',
#  './datasets\\monet2photo\\trainA\\00006.jpg',
#  './datasets\\monet2photo\\trainA\\00007.jpg',
#  './datasets\\monet2photo\\trainA\\00008.jpg',
#  './datasets\\monet2photo\\trainA\\00009.jpg',
#  './datasets\\monet2photo\\trainA\\00011.jpg',
#  './datasets\\monet2photo\\trainA\\00012.jpg',
#  './datasets\\monet2photo\\trainA\\00014.jpg',
#  './datasets\\monet2photo\\trainA\\00015.jpg',
#  './datasets\\monet2photo\\trainA\\00016.jpg',
#  './datasets\\monet2photo\\trainA\\00017.jpg',
#  './datasets\\monet2photo\\trainA\\00018.jpg',
#  './datasets\\monet2photo\\trainA\\00019.jpg',
#  './datasets\\monet2photo\\trainA\\00021.jpg',
#  './datasets\\monet2photo\\trainA\\00022.jpg',
#  './datasets\\monet2photo\\trainA\\00023.jpg',
#  './datasets\\monet2photo\\trainA\\00024.jpg',
#  './datasets\\monet2photo\\trainA\\00025.jpg',
#  './datasets\\monet2photo\\trainA\\00026.jpg',
#  './datasets\\monet2photo\\trainA\\00027.jpg',
#  './datasets\\monet2photo\\trainA\\00028.jpg',
#  './datasets\\monet2photo\\trainA\\00029.jpg',
#  './datasets\\monet2photo\\trainA\\00031.jpg',
#  './datasets\\monet2photo\\trainA\\00032.jpg',
#  './datasets\\monet2photo\\trainA\\00033.jpg',
#  './datasets\\monet2photo\\trainA\\00034.jpg',
#  './datasets\\monet2photo\\trainA\\00035.jpg',
#  './datasets\\monet2photo\\trainA\\00036.jpg',
#  './datasets\\monet2photo\\trainA\\00037.jpg',
#  './datasets\\monet2photo\\trainA\\00038.jpg',
#  './datasets\\monet2photo\\trainA\\00041.jpg',
#  './datasets\\monet2photo\\trainA\\00042.jpg',
#  './datasets\\monet2photo\\trainA\\00043.jpg',
#  './datasets\\monet2photo\\trainA\\00044.jpg',
#  './datasets\\monet2photo\\trainA\\00045.jpg',
#  './datasets\\monet2photo\\trainA\\00046.jpg',
#  './datasets\\monet2photo\\trainA\\00047.jpg',
#  './datasets\\monet2photo\\trainA\\00048.jpg',
#  './datasets\\monet2photo\\trainA\\00049.jpg',
#  './datasets\\monet2photo\\trainA\\00052.jpg',
#  './datasets\\monet2photo\\trainA\\00053.jpg',
#  './datasets\\monet2photo\\trainA\\00054.jpg',
#  './datasets\\monet2photo\\trainA\\00056.jpg',
#  './datasets\\monet2photo\\trainA\\00057.jpg',
#  './datasets\\monet2photo\\trainA\\00058.jpg',
#  './datasets\\monet2photo\\trainA\\00059.jpg',
#  './datasets\\monet2photo\\trainA\\00062.jpg',
#  './datasets\\monet2photo\\trainA\\00063.jpg',
#  './datasets\\monet2photo\\trainA\\00064.jpg',
#  './datasets\\monet2photo\\trainA\\00065.jpg',
#  './datasets\\monet2photo\\trainA\\00066.jpg',
#  './datasets\\monet2photo\\trainA\\00067.jpg',
#  './datasets\\monet2photo\\trainA\\00068.jpg',
#  './datasets\\monet2photo\\trainA\\00069.jpg',
#  './datasets\\monet2photo\\trainA\\00071.jpg',
#  './datasets\\monet2photo\\trainA\\00072.jpg',
#  './datasets\\monet2photo\\trainA\\00073.jpg',
#  './datasets\\monet2photo\\trainA\\00074.jpg',
#  './datasets\\monet2photo\\trainA\\00075.jpg',
#  './datasets\\monet2photo\\trainA\\00076.jpg',
#  './datasets\\monet2photo\\trainA\\00077.jpg',
#  './datasets\\monet2photo\\trainA\\00078.jpg',
#  './datasets\\monet2photo\\trainA\\00079.jpg',
#  './datasets\\monet2photo\\trainA\\00081.jpg',
#  './datasets\\monet2photo\\trainA\\00082.jpg',
#  './datasets\\monet2photo\\trainA\\00083.jpg',
#  './datasets\\monet2photo\\trainA\\00089.jpg',
#  './datasets\\monet2photo\\trainA\\00091.jpg',
#  './datasets\\monet2photo\\trainA\\00092.jpg',
#  './datasets\\monet2photo\\trainA\\00093.jpg',
#  './datasets\\monet2photo\\trainA\\00094.jpg',
#  './datasets\\monet2photo\\trainA\\00096.jpg',
#  './datasets\\monet2photo\\trainA\\00108.jpg',
#  './datasets\\monet2photo\\trainA\\00109.jpg',
#  './datasets\\monet2photo\\trainA\\00111.jpg',
#  './datasets\\monet2photo\\trainA\\00112.jpg',
#  './datasets\\monet2photo\\trainA\\00113.jpg',
#  './datasets\\monet2photo\\trainA\\00114.jpg',
#  './datasets\\monet2photo\\trainA\\00115.jpg',
#  './datasets\\monet2photo\\trainA\\00116.jpg',
#  './datasets\\monet2photo\\trainA\\00117.jpg',
#  './datasets\\monet2photo\\trainA\\00118.jpg',
#  './datasets\\monet2photo\\trainA\\00119.jpg',
#  './datasets\\monet2photo\\trainA\\00121.jpg',
#  './datasets\\monet2photo\\trainA\\00122.jpg',
#  './datasets\\monet2photo\\trainA\\00123.jpg',
#  './datasets\\monet2photo\\trainA\\00124.jpg',
#  './datasets\\monet2photo\\trainA\\00125.jpg',
#  './datasets\\monet2photo\\trainA\\00126.jpg',
#  './datasets\\monet2photo\\trainA\\00127.jpg',
#  './datasets\\monet2photo\\trainA\\00128.jpg',
#  './datasets\\monet2photo\\trainA\\00129.jpg',
#  './datasets\\monet2photo\\trainA\\00136.jpg',
#  './datasets\\monet2photo\\trainA\\00137.jpg',
#  './datasets\\monet2photo\\trainA\\00139.jpg',
#  './datasets\\monet2photo\\trainA\\00141.jpg',
#  './datasets\\monet2photo\\trainA\\00142.jpg',
#  './datasets\\monet2photo\\trainA\\00143.jpg',
#  './datasets\\monet2photo\\trainA\\00144.jpg',
#  './datasets\\monet2photo\\trainA\\00145.jpg',
#  './datasets\\monet2photo\\trainA\\00146.jpg',
#  './datasets\\monet2photo\\trainA\\00147.jpg',
#  './datasets\\monet2photo\\trainA\\00148.jpg',
#  './datasets\\monet2photo\\trainA\\00149.jpg',
#  './datasets\\monet2photo\\trainA\\00151.jpg',
#  './datasets\\monet2photo\\trainA\\00152.jpg',
#  './datasets\\monet2photo\\trainA\\00153.jpg',
#  './datasets\\monet2photo\\trainA\\00154.jpg',
#  './datasets\\monet2photo\\trainA\\00155.jpg',
#  './datasets\\monet2photo\\trainA\\00156.jpg',
#  './datasets\\monet2photo\\trainA\\00157.jpg',
#  './datasets\\monet2photo\\trainA\\00158.jpg',
#  './datasets\\monet2photo\\trainA\\00159.jpg',
#  './datasets\\monet2photo\\trainA\\00161.jpg',
#  './datasets\\monet2photo\\trainA\\00162.jpg',
#  './datasets\\monet2photo\\trainA\\00163.jpg',
#  './datasets\\monet2photo\\trainA\\00164.jpg',
#  './datasets\\monet2photo\\trainA\\00165.jpg',
#  './datasets\\monet2photo\\trainA\\00166.jpg',
#  './datasets\\monet2photo\\trainA\\00167.jpg',
#  './datasets\\monet2photo\\trainA\\00168.jpg',
#  './datasets\\monet2photo\\trainA\\00169.jpg',
#  './datasets\\monet2photo\\trainA\\00171.jpg',
#  './datasets\\monet2photo\\trainA\\00172.jpg',
#  './datasets\\monet2photo\\trainA\\00173.jpg',
#  './datasets\\monet2photo\\trainA\\00175.jpg',
#  './datasets\\monet2photo\\trainA\\00176.jpg',
#  './datasets\\monet2photo\\trainA\\00177.jpg',
#  './datasets\\monet2photo\\trainA\\00178.jpg',
#  './datasets\\monet2photo\\trainA\\00179.jpg',
#  './datasets\\monet2photo\\trainA\\00184.jpg',
#  './datasets\\monet2photo\\trainA\\00185.jpg',
#  './datasets\\monet2photo\\trainA\\00186.jpg',
#  './datasets\\monet2photo\\trainA\\00187.jpg',
#  './datasets\\monet2photo\\trainA\\00188.jpg',
#  './datasets\\monet2photo\\trainA\\00189.jpg',
#  './datasets\\monet2photo\\trainA\\00191.jpg',
#  './datasets\\monet2photo\\trainA\\00192.jpg',
#  './datasets\\monet2photo\\trainA\\00193.jpg',
#  './datasets\\monet2photo\\trainA\\00194.jpg',
#  './datasets\\monet2photo\\trainA\\00195.jpg',
#  './datasets\\monet2photo\\trainA\\00196.jpg',
#  './datasets\\monet2photo\\trainA\\00197.jpg',
#  './datasets\\monet2photo\\trainA\\00198.jpg',
#  './datasets\\monet2photo\\trainA\\00199.jpg',
#  './datasets\\monet2photo\\trainA\\00201.jpg',
#  './datasets\\monet2photo\\trainA\\00202.jpg',
#  './datasets\\monet2photo\\trainA\\00203.jpg',
#  './datasets\\monet2photo\\trainA\\00204.jpg',
#  './datasets\\monet2photo\\trainA\\00205.jpg',
#  './datasets\\monet2photo\\trainA\\00206.jpg',
#  './datasets\\monet2photo\\trainA\\00207.jpg',
#  './datasets\\monet2photo\\trainA\\00208.jpg',
#  './datasets\\monet2photo\\trainA\\00209.jpg',
#  './datasets\\monet2photo\\trainA\\00211.jpg',
#  './datasets\\monet2photo\\trainA\\00212.jpg',
#  './datasets\\monet2photo\\trainA\\00213.jpg',
#  './datasets\\monet2photo\\trainA\\00214.jpg',
#  './datasets\\monet2photo\\trainA\\00215.jpg',
#  './datasets\\monet2photo\\trainA\\00216.jpg',
#  './datasets\\monet2photo\\trainA\\00217.jpg',
#  './datasets\\monet2photo\\trainA\\00218.jpg',
#  './datasets\\monet2photo\\trainA\\00219.jpg',
#  './datasets\\monet2photo\\trainA\\00221.jpg',
#  './datasets\\monet2photo\\trainA\\00222.jpg',
#  './datasets\\monet2photo\\trainA\\00223.jpg',
#  './datasets\\monet2photo\\trainA\\00224.jpg',
#  './datasets\\monet2photo\\trainA\\00225.jpg',
#  './datasets\\monet2photo\\trainA\\00226.jpg',
#  './datasets\\monet2photo\\trainA\\00227.jpg',
#  './datasets\\monet2photo\\trainA\\00229.jpg',
#  './datasets\\monet2photo\\trainA\\00231.jpg',
#  './datasets\\monet2photo\\trainA\\00232.jpg',
#  './datasets\\monet2photo\\trainA\\00233.jpg',
#  './datasets\\monet2photo\\trainA\\00234.jpg',
#  './datasets\\monet2photo\\trainA\\00235.jpg',
#  './datasets\\monet2photo\\trainA\\00236.jpg',
#  './datasets\\monet2photo\\trainA\\00238.jpg',
#  './datasets\\monet2photo\\trainA\\00239.jpg',
#  './datasets\\monet2photo\\trainA\\00241.jpg',
#  './datasets\\monet2photo\\trainA\\00242.jpg',
#  './datasets\\monet2photo\\trainA\\00243.jpg',
#  './datasets\\monet2photo\\trainA\\00244.jpg',
#  './datasets\\monet2photo\\trainA\\00245.jpg',
#  './datasets\\monet2photo\\trainA\\00246.jpg',
#  './datasets\\monet2photo\\trainA\\00247.jpg',
#  './datasets\\monet2photo\\trainA\\00248.jpg',
#  './datasets\\monet2photo\\trainA\\00249.jpg',
#  './datasets\\monet2photo\\trainA\\00251.jpg',
#  './datasets\\monet2photo\\trainA\\00252.jpg',
#  './datasets\\monet2photo\\trainA\\00255.jpg',
#  './datasets\\monet2photo\\trainA\\00256.jpg',
#  './datasets\\monet2photo\\trainA\\00257.jpg',
#  './datasets\\monet2photo\\trainA\\00258.jpg',
#  './datasets\\monet2photo\\trainA\\00259.jpg',
#  './datasets\\monet2photo\\trainA\\00261.jpg',
#  './datasets\\monet2photo\\trainA\\00262.jpg',
#  './datasets\\monet2photo\\trainA\\00263.jpg',
#  './datasets\\monet2photo\\trainA\\00264.jpg',
#  './datasets\\monet2photo\\trainA\\00265.jpg',
#  './datasets\\monet2photo\\trainA\\00266.jpg',
#  './datasets\\monet2photo\\trainA\\00267.jpg',
#  './datasets\\monet2photo\\trainA\\00268.jpg',
#  './datasets\\monet2photo\\trainA\\00269.jpg',
#  './datasets\\monet2photo\\trainA\\00271.jpg',
#  './datasets\\monet2photo\\trainA\\00272.jpg',
#  './datasets\\monet2photo\\trainA\\00273.jpg',
#  './datasets\\monet2photo\\trainA\\00274.jpg',
#  './datasets\\monet2photo\\trainA\\00275.jpg',
#  './datasets\\monet2photo\\trainA\\00276.jpg',
#  './datasets\\monet2photo\\trainA\\00277.jpg',
#  './datasets\\monet2photo\\trainA\\00278.jpg',
#  './datasets\\monet2photo\\trainA\\00281.jpg',
#  './datasets\\monet2photo\\trainA\\00282.jpg',
#  './datasets\\monet2photo\\trainA\\00283.jpg',
#  './datasets\\monet2photo\\trainA\\00284.jpg',
#  './datasets\\monet2photo\\trainA\\00285.jpg',
#  './datasets\\monet2photo\\trainA\\00286.jpg',
#  './datasets\\monet2photo\\trainA\\00287.jpg',
#  './datasets\\monet2photo\\trainA\\00288.jpg',
#  './datasets\\monet2photo\\trainA\\00289.jpg',
#  './datasets\\monet2photo\\trainA\\00291.jpg',
#  './datasets\\monet2photo\\trainA\\00292.jpg',
#  './datasets\\monet2photo\\trainA\\00294.jpg',
#  './datasets\\monet2photo\\trainA\\00295.jpg',
#  './datasets\\monet2photo\\trainA\\00296.jpg',
#  './datasets\\monet2photo\\trainA\\00297.jpg',
#  './datasets\\monet2photo\\trainA\\00298.jpg',
#  './datasets\\monet2photo\\trainA\\00299.jpg',
#  './datasets\\monet2photo\\trainA\\00301.jpg',
#  './datasets\\monet2photo\\trainA\\00302.jpg',
#  './datasets\\monet2photo\\trainA\\00303.jpg',
#  './datasets\\monet2photo\\trainA\\00304.jpg',
#  './datasets\\monet2photo\\trainA\\00305.jpg',
#  './datasets\\monet2photo\\trainA\\00306.jpg',
#  './datasets\\monet2photo\\trainA\\00307.jpg',
#  './datasets\\monet2photo\\trainA\\00308.jpg',
#  './datasets\\monet2photo\\trainA\\00309.jpg',
#  './datasets\\monet2photo\\trainA\\00311.jpg',
#  './datasets\\monet2photo\\trainA\\00312.jpg',
#  './datasets\\monet2photo\\trainA\\00313.jpg',
#  './datasets\\monet2photo\\trainA\\00314.jpg',
#  './datasets\\monet2photo\\trainA\\00315.jpg',
#  './datasets\\monet2photo\\trainA\\00316.jpg',
#  './datasets\\monet2photo\\trainA\\00317.jpg',
#  './datasets\\monet2photo\\trainA\\00318.jpg',
#  './datasets\\monet2photo\\trainA\\00319.jpg',
#  './datasets\\monet2photo\\trainA\\00321.jpg',
#  './datasets\\monet2photo\\trainA\\00323.jpg',
#  './datasets\\monet2photo\\trainA\\00324.jpg',
#  './datasets\\monet2photo\\trainA\\00325.jpg',
#  './datasets\\monet2photo\\trainA\\00326.jpg',
#  './datasets\\monet2photo\\trainA\\00327.jpg',
#  './datasets\\monet2photo\\trainA\\00328.jpg',
#  './datasets\\monet2photo\\trainA\\00329.jpg',
#  './datasets\\monet2photo\\trainA\\00331.jpg',
#  './datasets\\monet2photo\\trainA\\00332.jpg',
#  './datasets\\monet2photo\\trainA\\00333.jpg',
#  './datasets\\monet2photo\\trainA\\00334.jpg',
#  './datasets\\monet2photo\\trainA\\00335.jpg',
#  './datasets\\monet2photo\\trainA\\00336.jpg',
#  './datasets\\monet2photo\\trainA\\00342.jpg',
#  './datasets\\monet2photo\\trainA\\00343.jpg',
#  './datasets\\monet2photo\\trainA\\00344.jpg',
#  './datasets\\monet2photo\\trainA\\00345.jpg',
#  './datasets\\monet2photo\\trainA\\00346.jpg',
#  './datasets\\monet2photo\\trainA\\00348.jpg',
#  './datasets\\monet2photo\\trainA\\00349.jpg',
#  './datasets\\monet2photo\\trainA\\00351.jpg',
#  './datasets\\monet2photo\\trainA\\00352.jpg',
#  './datasets\\monet2photo\\trainA\\00353.jpg',
#  './datasets\\monet2photo\\trainA\\00354.jpg',
#  './datasets\\monet2photo\\trainA\\00355.jpg',
#  './datasets\\monet2photo\\trainA\\00356.jpg',
#  './datasets\\monet2photo\\trainA\\00357.jpg',
#  './datasets\\monet2photo\\trainA\\00358.jpg',
#  './datasets\\monet2photo\\trainA\\00361.jpg',
#  './datasets\\monet2photo\\trainA\\00362.jpg',
#  './datasets\\monet2photo\\trainA\\00363.jpg',
#  './datasets\\monet2photo\\trainA\\00364.jpg',
#  './datasets\\monet2photo\\trainA\\00365.jpg',
#  './datasets\\monet2photo\\trainA\\00366.jpg',
#  './datasets\\monet2photo\\trainA\\00367.jpg',
#  './datasets\\monet2photo\\trainA\\00368.jpg',
#  './datasets\\monet2photo\\trainA\\00376.jpg',
#  './datasets\\monet2photo\\trainA\\00377.jpg',
#  './datasets\\monet2photo\\trainA\\00378.jpg',
#  './datasets\\monet2photo\\trainA\\00379.jpg',
#  './datasets\\monet2photo\\trainA\\00381.jpg',
#  './datasets\\monet2photo\\trainA\\00382.jpg',
#  './datasets\\monet2photo\\trainA\\00383.jpg',
#  './datasets\\monet2photo\\trainA\\00385.jpg',
#  './datasets\\monet2photo\\trainA\\00386.jpg',
#  './datasets\\monet2photo\\trainA\\00387.jpg',
#  './datasets\\monet2photo\\trainA\\00388.jpg',
#  './datasets\\monet2photo\\trainA\\00389.jpg',
#  './datasets\\monet2photo\\trainA\\00391.jpg',
#  './datasets\\monet2photo\\trainA\\00392.jpg',
#  './datasets\\monet2photo\\trainA\\00393.jpg',
#  './datasets\\monet2photo\\trainA\\00394.jpg',
#  './datasets\\monet2photo\\trainA\\00395.jpg',
#  './datasets\\monet2photo\\trainA\\00396.jpg',
#  './datasets\\monet2photo\\trainA\\00397.jpg',
#  './datasets\\monet2photo\\trainA\\00398.jpg',
#  './datasets\\monet2photo\\trainA\\00399.jpg',
#  './datasets\\monet2photo\\trainA\\00401.jpg',
#  './datasets\\monet2photo\\trainA\\00402.jpg',
#  './datasets\\monet2photo\\trainA\\00403.jpg',
#  './datasets\\monet2photo\\trainA\\00404.jpg',
#  './datasets\\monet2photo\\trainA\\00405.jpg',
#  './datasets\\monet2photo\\trainA\\00406.jpg',
#  './datasets\\monet2photo\\trainA\\00407.jpg',
#  './datasets\\monet2photo\\trainA\\00408.jpg',
#  './datasets\\monet2photo\\trainA\\00409.jpg',
#  './datasets\\monet2photo\\trainA\\00411.jpg',
#  './datasets\\monet2photo\\trainA\\00412.jpg',
#  './datasets\\monet2photo\\trainA\\00413.jpg',
#  './datasets\\monet2photo\\trainA\\00414.jpg',
#  './datasets\\monet2photo\\trainA\\00415.jpg',
#  './datasets\\monet2photo\\trainA\\00416.jpg',
#  './datasets\\monet2photo\\trainA\\00417.jpg',
#  './datasets\\monet2photo\\trainA\\00421.jpg',
#  './datasets\\monet2photo\\trainA\\00422.jpg',
#  './datasets\\monet2photo\\trainA\\00423.jpg',
#  './datasets\\monet2photo\\trainA\\00424.jpg',
#  './datasets\\monet2photo\\trainA\\00425.jpg',
#  './datasets\\monet2photo\\trainA\\00426.jpg',
#  './datasets\\monet2photo\\trainA\\00427.jpg',
#  './datasets\\monet2photo\\trainA\\00428.jpg',
#  './datasets\\monet2photo\\trainA\\00429.jpg',
#  './datasets\\monet2photo\\trainA\\00431.jpg',
#  './datasets\\monet2photo\\trainA\\00432.jpg',
#  './datasets\\monet2photo\\trainA\\00433.jpg',
#  './datasets\\monet2photo\\trainA\\00435.jpg',
#  './datasets\\monet2photo\\trainA\\00436.jpg',
#  './datasets\\monet2photo\\trainA\\00437.jpg',
#  './datasets\\monet2photo\\trainA\\00438.jpg',
#  './datasets\\monet2photo\\trainA\\00439.jpg',
#  './datasets\\monet2photo\\trainA\\00441.jpg',
#  './datasets\\monet2photo\\trainA\\00442.jpg',
#  './datasets\\monet2photo\\trainA\\00443.jpg',
#  './datasets\\monet2photo\\trainA\\00444.jpg',
#  './datasets\\monet2photo\\trainA\\00445.jpg',
#  './datasets\\monet2photo\\trainA\\00446.jpg',
#  './datasets\\monet2photo\\trainA\\00447.jpg',
#  './datasets\\monet2photo\\trainA\\00448.jpg',
#  './datasets\\monet2photo\\trainA\\00449.jpg',
#  './datasets\\monet2photo\\trainA\\00451.jpg',
#  './datasets\\monet2photo\\trainA\\00452.jpg',
#  './datasets\\monet2photo\\trainA\\00453.jpg',
#  './datasets\\monet2photo\\trainA\\00454.jpg',
#  './datasets\\monet2photo\\trainA\\00455.jpg',
#  './datasets\\monet2photo\\trainA\\00456.jpg',
#  './datasets\\monet2photo\\trainA\\00457.jpg',
#  './datasets\\monet2photo\\trainA\\00458.jpg',
#  './datasets\\monet2photo\\trainA\\00459.jpg',
#  './datasets\\monet2photo\\trainA\\00461.jpg',
#  './datasets\\monet2photo\\trainA\\00462.jpg',
#  './datasets\\monet2photo\\trainA\\00463.jpg',
#  './datasets\\monet2photo\\trainA\\00464.jpg',
#  './datasets\\monet2photo\\trainA\\00465.jpg',
#  './datasets\\monet2photo\\trainA\\00466.jpg',
#  './datasets\\monet2photo\\trainA\\00467.jpg',
#  './datasets\\monet2photo\\trainA\\00468.jpg',
#  './datasets\\monet2photo\\trainA\\00469.jpg',
#  './datasets\\monet2photo\\trainA\\00471.jpg',
#  './datasets\\monet2photo\\trainA\\00472.jpg',
#  './datasets\\monet2photo\\trainA\\00475.jpg',
#  './datasets\\monet2photo\\trainA\\00476.jpg',
#  './datasets\\monet2photo\\trainA\\00477.jpg',
#  './datasets\\monet2photo\\trainA\\00478.jpg',
#  './datasets\\monet2photo\\trainA\\00479.jpg',
#  './datasets\\monet2photo\\trainA\\00481.jpg',
#  './datasets\\monet2photo\\trainA\\00482.jpg',
#  './datasets\\monet2photo\\trainA\\00483.jpg',
#  './datasets\\monet2photo\\trainA\\00484.jpg',
#  './datasets\\monet2photo\\trainA\\00485.jpg',
#  './datasets\\monet2photo\\trainA\\00486.jpg',
#  './datasets\\monet2photo\\trainA\\00487.jpg',
#  './datasets\\monet2photo\\trainA\\00488.jpg',
#  './datasets\\monet2photo\\trainA\\00489.jpg',
#  './datasets\\monet2photo\\trainA\\00491.jpg',
#  './datasets\\monet2photo\\trainA\\00492.jpg',
#  './datasets\\monet2photo\\trainA\\00493.jpg',
#  './datasets\\monet2photo\\trainA\\00494.jpg',
#  './datasets\\monet2photo\\trainA\\00495.jpg',
#  './datasets\\monet2photo\\trainA\\00496.jpg',
#  './datasets\\monet2photo\\trainA\\00497.jpg',
#  './datasets\\monet2photo\\trainA\\00498.jpg',
#  './datasets\\monet2photo\\trainA\\00499.jpg',
#  './datasets\\monet2photo\\trainA\\00501.jpg',
#  './datasets\\monet2photo\\trainA\\00502.jpg',
#  './datasets\\monet2photo\\trainA\\00503.jpg',
#  './datasets\\monet2photo\\trainA\\00504.jpg',
#  './datasets\\monet2photo\\trainA\\00505.jpg',
#  './datasets\\monet2photo\\trainA\\00506.jpg',
#  './datasets\\monet2photo\\trainA\\00507.jpg',
#  './datasets\\monet2photo\\trainA\\00518.jpg',
#  './datasets\\monet2photo\\trainA\\00519.jpg',
#  './datasets\\monet2photo\\trainA\\00521.jpg',
#  './datasets\\monet2photo\\trainA\\00522.jpg',
#  './datasets\\monet2photo\\trainA\\00523.jpg',
#  './datasets\\monet2photo\\trainA\\00524.jpg',
#  './datasets\\monet2photo\\trainA\\00525.jpg',
#  './datasets\\monet2photo\\trainA\\00526.jpg',
#  './datasets\\monet2photo\\trainA\\00527.jpg',
#  './datasets\\monet2photo\\trainA\\00528.jpg',
#  './datasets\\monet2photo\\trainA\\00529.jpg',
#  './datasets\\monet2photo\\trainA\\00533.jpg',
#  './datasets\\monet2photo\\trainA\\00534.jpg',
#  './datasets\\monet2photo\\trainA\\00535.jpg',
#  './datasets\\monet2photo\\trainA\\00536.jpg',
#  './datasets\\monet2photo\\trainA\\00537.jpg',
#  './datasets\\monet2photo\\trainA\\00538.jpg',
#  './datasets\\monet2photo\\trainA\\00539.jpg',
#  './datasets\\monet2photo\\trainA\\00541.jpg',
#  './datasets\\monet2photo\\trainA\\00542.jpg',
#  './datasets\\monet2photo\\trainA\\00543.jpg',
#  './datasets\\monet2photo\\trainA\\00544.jpg',
#  './datasets\\monet2photo\\trainA\\00545.jpg',
#  './datasets\\monet2photo\\trainA\\00546.jpg',
#  './datasets\\monet2photo\\trainA\\00547.jpg',
#  './datasets\\monet2photo\\trainA\\00548.jpg',
#  './datasets\\monet2photo\\trainA\\00549.jpg',
#  './datasets\\monet2photo\\trainA\\00551.jpg',
#  './datasets\\monet2photo\\trainA\\00552.jpg',
#  './datasets\\monet2photo\\trainA\\00553.jpg',
#  './datasets\\monet2photo\\trainA\\00554.jpg',
#  './datasets\\monet2photo\\trainA\\00555.jpg',
#  './datasets\\monet2photo\\trainA\\00556.jpg',
#  './datasets\\monet2photo\\trainA\\00557.jpg',
#  './datasets\\monet2photo\\trainA\\00558.jpg',
#  './datasets\\monet2photo\\trainA\\00559.jpg',
#  './datasets\\monet2photo\\trainA\\00588.jpg',
#  './datasets\\monet2photo\\trainA\\00589.jpg',
#  './datasets\\monet2photo\\trainA\\00591.jpg',
#  './datasets\\monet2photo\\trainA\\00592.jpg',
#  './datasets\\monet2photo\\trainA\\00593.jpg',
#  './datasets\\monet2photo\\trainA\\00594.jpg',
#  './datasets\\monet2photo\\trainA\\00595.jpg',
#  './datasets\\monet2photo\\trainA\\00596.jpg',
#  './datasets\\monet2photo\\trainA\\00597.jpg',
#  './datasets\\monet2photo\\trainA\\00598.jpg',
#  './datasets\\monet2photo\\trainA\\00599.jpg',
#  './datasets\\monet2photo\\trainA\\00601.jpg',
#  './datasets\\monet2photo\\trainA\\00602.jpg',
#  './datasets\\monet2photo\\trainA\\00603.jpg',
#  './datasets\\monet2photo\\trainA\\00606.jpg',
#  './datasets\\monet2photo\\trainA\\00607.jpg',
#  './datasets\\monet2photo\\trainA\\00608.jpg',
#  './datasets\\monet2photo\\trainA\\00609.jpg',
#  './datasets\\monet2photo\\trainA\\00611.jpg',
#  './datasets\\monet2photo\\trainA\\00612.jpg',
#  './datasets\\monet2photo\\trainA\\00613.jpg',
#  './datasets\\monet2photo\\trainA\\00614.jpg',
#  './datasets\\monet2photo\\trainA\\00615.jpg',
#  './datasets\\monet2photo\\trainA\\00616.jpg',
#  './datasets\\monet2photo\\trainA\\00617.jpg',
#  './datasets\\monet2photo\\trainA\\00618.jpg',
#  './datasets\\monet2photo\\trainA\\00619.jpg',
#  './datasets\\monet2photo\\trainA\\00621.jpg',
#  './datasets\\monet2photo\\trainA\\00622.jpg',
#  './datasets\\monet2photo\\trainA\\00623.jpg',
#  './datasets\\monet2photo\\trainA\\00624.jpg',
#  './datasets\\monet2photo\\trainA\\00625.jpg',
#  './datasets\\monet2photo\\trainA\\00626.jpg',
#  './datasets\\monet2photo\\trainA\\00627.jpg',
#  './datasets\\monet2photo\\trainA\\00631.jpg',
#  './datasets\\monet2photo\\trainA\\00632.jpg',
#  './datasets\\monet2photo\\trainA\\00633.jpg',
#  './datasets\\monet2photo\\trainA\\00634.jpg',
#  './datasets\\monet2photo\\trainA\\00635.jpg',
#  './datasets\\monet2photo\\trainA\\00636.jpg',
#  './datasets\\monet2photo\\trainA\\00637.jpg',
#  './datasets\\monet2photo\\trainA\\00638.jpg',
#  './datasets\\monet2photo\\trainA\\00639.jpg',
#  './datasets\\monet2photo\\trainA\\00641.jpg',
#  './datasets\\monet2photo\\trainA\\00642.jpg',
#  './datasets\\monet2photo\\trainA\\00643.jpg',
#  './datasets\\monet2photo\\trainA\\00644.jpg',
#  './datasets\\monet2photo\\trainA\\00645.jpg',
#  './datasets\\monet2photo\\trainA\\00646.jpg',
#  './datasets\\monet2photo\\trainA\\00647.jpg',
#  './datasets\\monet2photo\\trainA\\00648.jpg',
#  './datasets\\monet2photo\\trainA\\00649.jpg',
#  './datasets\\monet2photo\\trainA\\00651.jpg',
#  './datasets\\monet2photo\\trainA\\00652.jpg',
#  './datasets\\monet2photo\\trainA\\00653.jpg',
#  './datasets\\monet2photo\\trainA\\00654.jpg',
#  './datasets\\monet2photo\\trainA\\00655.jpg',
#  './datasets\\monet2photo\\trainA\\00656.jpg',
#  './datasets\\monet2photo\\trainA\\00657.jpg',
#  './datasets\\monet2photo\\trainA\\00658.jpg',
#  './datasets\\monet2photo\\trainA\\00659.jpg',
#  './datasets\\monet2photo\\trainA\\00666.jpg',
#  './datasets\\monet2photo\\trainA\\00667.jpg',
#  './datasets\\monet2photo\\trainA\\00668.jpg',
#  './datasets\\monet2photo\\trainA\\00669.jpg',
#  './datasets\\monet2photo\\trainA\\00671.jpg',
#  './datasets\\monet2photo\\trainA\\00672.jpg',
#  './datasets\\monet2photo\\trainA\\00673.jpg',
#  './datasets\\monet2photo\\trainA\\00674.jpg',
#  './datasets\\monet2photo\\trainA\\00675.jpg',
#  './datasets\\monet2photo\\trainA\\00676.jpg',
#  './datasets\\monet2photo\\trainA\\00677.jpg',
#  './datasets\\monet2photo\\trainA\\00678.jpg',
#  './datasets\\monet2photo\\trainA\\00679.jpg',
#  './datasets\\monet2photo\\trainA\\00681.jpg',
#  './datasets\\monet2photo\\trainA\\00682.jpg',
#  './datasets\\monet2photo\\trainA\\00683.jpg',
#  './datasets\\monet2photo\\trainA\\00684.jpg',
#  './datasets\\monet2photo\\trainA\\00685.jpg',
#  './datasets\\monet2photo\\trainA\\00686.jpg',
#  './datasets\\monet2photo\\trainA\\00687.jpg',
#  './datasets\\monet2photo\\trainA\\00688.jpg',
#  './datasets\\monet2photo\\trainA\\00689.jpg',
#  './datasets\\monet2photo\\trainA\\00691.jpg',
#  './datasets\\monet2photo\\trainA\\00693.jpg',
#  './datasets\\monet2photo\\trainA\\00694.jpg',
#  './datasets\\monet2photo\\trainA\\00695.jpg',
#  './datasets\\monet2photo\\trainA\\00696.jpg',
#  './datasets\\monet2photo\\trainA\\00697.jpg',
#  './datasets\\monet2photo\\trainA\\00698.jpg',
#  './datasets\\monet2photo\\trainA\\00699.jpg',
#  './datasets\\monet2photo\\trainA\\00701.jpg',
#  './datasets\\monet2photo\\trainA\\00702.jpg',
#  './datasets\\monet2photo\\trainA\\00703.jpg',
#  './datasets\\monet2photo\\trainA\\00704.jpg',
#  './datasets\\monet2photo\\trainA\\00705.jpg',
#  './datasets\\monet2photo\\trainA\\00706.jpg',
#  './datasets\\monet2photo\\trainA\\00707.jpg',
#  './datasets\\monet2photo\\trainA\\00708.jpg',
#  './datasets\\monet2photo\\trainA\\00709.jpg',
#  './datasets\\monet2photo\\trainA\\00711.jpg',
#  './datasets\\monet2photo\\trainA\\00712.jpg',
#  './datasets\\monet2photo\\trainA\\00713.jpg',
#  './datasets\\monet2photo\\trainA\\00714.jpg',
#  './datasets\\monet2photo\\trainA\\00715.jpg',
#  './datasets\\monet2photo\\trainA\\00716.jpg',
#  './datasets\\monet2photo\\trainA\\00717.jpg',
#  './datasets\\monet2photo\\trainA\\00718.jpg',
#  './datasets\\monet2photo\\trainA\\00719.jpg',
#  './datasets\\monet2photo\\trainA\\00721.jpg',
#  './datasets\\monet2photo\\trainA\\00722.jpg',
#  './datasets\\monet2photo\\trainA\\00723.jpg',
#  './datasets\\monet2photo\\trainA\\00724.jpg',
#  './datasets\\monet2photo\\trainA\\00725.jpg',
#  './datasets\\monet2photo\\trainA\\00726.jpg',
#  './datasets\\monet2photo\\trainA\\00727.jpg',
#  './datasets\\monet2photo\\trainA\\00728.jpg',
#  './datasets\\monet2photo\\trainA\\00729.jpg',
#  './datasets\\monet2photo\\trainA\\00731.jpg',
#  './datasets\\monet2photo\\trainA\\00732.jpg',
#  './datasets\\monet2photo\\trainA\\00733.jpg',
#  './datasets\\monet2photo\\trainA\\00734.jpg',
#  './datasets\\monet2photo\\trainA\\00735.jpg',
#  './datasets\\monet2photo\\trainA\\00736.jpg',
#  './datasets\\monet2photo\\trainA\\00737.jpg',
#  './datasets\\monet2photo\\trainA\\00738.jpg',
#  './datasets\\monet2photo\\trainA\\00739.jpg',
#  './datasets\\monet2photo\\trainA\\00741.jpg',
#  './datasets\\monet2photo\\trainA\\00742.jpg',
#  './datasets\\monet2photo\\trainA\\00743.jpg',
#  './datasets\\monet2photo\\trainA\\00744.jpg',
#  './datasets\\monet2photo\\trainA\\00745.jpg',
#  './datasets\\monet2photo\\trainA\\00746.jpg',
#  './datasets\\monet2photo\\trainA\\00747.jpg',
#  './datasets\\monet2photo\\trainA\\00748.jpg',
#  './datasets\\monet2photo\\trainA\\00749.jpg',
#  './datasets\\monet2photo\\trainA\\00751.jpg',
#  './datasets\\monet2photo\\trainA\\00752.jpg',
#  './datasets\\monet2photo\\trainA\\00753.jpg',
#  './datasets\\monet2photo\\trainA\\00754.jpg',
#  './datasets\\monet2photo\\trainA\\00755.jpg',
#  './datasets\\monet2photo\\trainA\\00756.jpg',
#  './datasets\\monet2photo\\trainA\\00757.jpg',
#  './datasets\\monet2photo\\trainA\\00758.jpg',
#  './datasets\\monet2photo\\trainA\\00759.jpg',
#  './datasets\\monet2photo\\trainA\\00761.jpg',
#  './datasets\\monet2photo\\trainA\\00762.jpg',
#  './datasets\\monet2photo\\trainA\\00763.jpg',
#  './datasets\\monet2photo\\trainA\\00767.jpg',
#  './datasets\\monet2photo\\trainA\\00768.jpg',
#  './datasets\\monet2photo\\trainA\\00769.jpg',
#  './datasets\\monet2photo\\trainA\\00771.jpg',
#  './datasets\\monet2photo\\trainA\\00772.jpg',
#  './datasets\\monet2photo\\trainA\\00773.jpg',
#  './datasets\\monet2photo\\trainA\\00774.jpg',
#  './datasets\\monet2photo\\trainA\\00775.jpg',
#  './datasets\\monet2photo\\trainA\\00776.jpg',
#  './datasets\\monet2photo\\trainA\\00777.jpg',
#  './datasets\\monet2photo\\trainA\\00778.jpg',
#  './datasets\\monet2photo\\trainA\\00779.jpg',
#  './datasets\\monet2photo\\trainA\\00781.jpg',
#  './datasets\\monet2photo\\trainA\\00783.jpg',
#  './datasets\\monet2photo\\trainA\\00784.jpg',
#  './datasets\\monet2photo\\trainA\\00786.jpg',
#  './datasets\\monet2photo\\trainA\\00787.jpg',
#  './datasets\\monet2photo\\trainA\\00788.jpg',
#  './datasets\\monet2photo\\trainA\\00789.jpg',
#  './datasets\\monet2photo\\trainA\\00791.jpg',
#  './datasets\\monet2photo\\trainA\\00792.jpg',
#  './datasets\\monet2photo\\trainA\\00793.jpg',
#  './datasets\\monet2photo\\trainA\\00794.jpg',
#  './datasets\\monet2photo\\trainA\\00795.jpg',
#  './datasets\\monet2photo\\trainA\\00796.jpg',
#  './datasets\\monet2photo\\trainA\\00797.jpg',
#  './datasets\\monet2photo\\trainA\\00798.jpg',
#  './datasets\\monet2photo\\trainA\\00799.jpg',
#  './datasets\\monet2photo\\trainA\\00801.jpg',
#  './datasets\\monet2photo\\trainA\\00802.jpg',
#  './datasets\\monet2photo\\trainA\\00803.jpg',
#  './datasets\\monet2photo\\trainA\\00804.jpg',
#  './datasets\\monet2photo\\trainA\\00805.jpg',
#  './datasets\\monet2photo\\trainA\\00806.jpg',
#  './datasets\\monet2photo\\trainA\\00807.jpg',
#  './datasets\\monet2photo\\trainA\\00808.jpg',
#  './datasets\\monet2photo\\trainA\\00809.jpg',
#  './datasets\\monet2photo\\trainA\\00811.jpg',
#  './datasets\\monet2photo\\trainA\\00812.jpg',
#  './datasets\\monet2photo\\trainA\\00813.jpg',
#  './datasets\\monet2photo\\trainA\\00814.jpg',
#  './datasets\\monet2photo\\trainA\\00815.jpg',
#  './datasets\\monet2photo\\trainA\\00816.jpg',
#  './datasets\\monet2photo\\trainA\\00817.jpg',
#  './datasets\\monet2photo\\trainA\\00818.jpg',
#  './datasets\\monet2photo\\trainA\\00819.jpg',
#  './datasets\\monet2photo\\trainA\\00821.jpg',
#  './datasets\\monet2photo\\trainA\\00822.jpg',
#  './datasets\\monet2photo\\trainA\\00823.jpg',
#  './datasets\\monet2photo\\trainA\\00824.jpg',
#  './datasets\\monet2photo\\trainA\\00825.jpg',
#  './datasets\\monet2photo\\trainA\\00826.jpg',
#  './datasets\\monet2photo\\trainA\\00827.jpg',
#  './datasets\\monet2photo\\trainA\\00828.jpg',
#  './datasets\\monet2photo\\trainA\\00829.jpg',
#  './datasets\\monet2photo\\trainA\\00831.jpg',
#  './datasets\\monet2photo\\trainA\\00832.jpg',
#  './datasets\\monet2photo\\trainA\\00833.jpg',
#  './datasets\\monet2photo\\trainA\\00834.jpg',
#  './datasets\\monet2photo\\trainA\\00835.jpg',
#  './datasets\\monet2photo\\trainA\\00836.jpg',
#  './datasets\\monet2photo\\trainA\\00837.jpg',
#  './datasets\\monet2photo\\trainA\\00838.jpg',
#  './datasets\\monet2photo\\trainA\\00839.jpg',
#  './datasets\\monet2photo\\trainA\\00841.jpg',
#  './datasets\\monet2photo\\trainA\\00842.jpg',
#  './datasets\\monet2photo\\trainA\\00843.jpg',
#  './datasets\\monet2photo\\trainA\\00844.jpg',
#  './datasets\\monet2photo\\trainA\\00845.jpg',
#  './datasets\\monet2photo\\trainA\\00846.jpg',
#  './datasets\\monet2photo\\trainA\\00847.jpg',
#  './datasets\\monet2photo\\trainA\\00848.jpg',
#  './datasets\\monet2photo\\trainA\\00849.jpg',
#  './datasets\\monet2photo\\trainA\\00851.jpg',
#  './datasets\\monet2photo\\trainA\\00852.jpg',
#  './datasets\\monet2photo\\trainA\\00856.jpg',
#  './datasets\\monet2photo\\trainA\\00857.jpg',
#  './datasets\\monet2photo\\trainA\\00858.jpg',
#  './datasets\\monet2photo\\trainA\\00859.jpg',
#  './datasets\\monet2photo\\trainA\\00861.jpg',
#  './datasets\\monet2photo\\trainA\\00862.jpg',
#  './datasets\\monet2photo\\trainA\\00863.jpg',
#  './datasets\\monet2photo\\trainA\\00864.jpg',
#  './datasets\\monet2photo\\trainA\\00865.jpg',
#  './datasets\\monet2photo\\trainA\\00866.jpg',
#  './datasets\\monet2photo\\trainA\\00867.jpg',
#  './datasets\\monet2photo\\trainA\\00868.jpg',
#  './datasets\\monet2photo\\trainA\\00869.jpg',
#  './datasets\\monet2photo\\trainA\\00871.jpg',
#  './datasets\\monet2photo\\trainA\\00872.jpg',
#  './datasets\\monet2photo\\trainA\\00873.jpg',
#  './datasets\\monet2photo\\trainA\\00874.jpg',
#  './datasets\\monet2photo\\trainA\\00875.jpg',
#  './datasets\\monet2photo\\trainA\\00876.jpg',
#  './datasets\\monet2photo\\trainA\\00877.jpg',
#  './datasets\\monet2photo\\trainA\\00878.jpg',
#  './datasets\\monet2photo\\trainA\\00879.jpg',
#  './datasets\\monet2photo\\trainA\\00881.jpg',
#  './datasets\\monet2photo\\trainA\\00882.jpg',
#  './datasets\\monet2photo\\trainA\\00883.jpg',
#  './datasets\\monet2photo\\trainA\\00884.jpg',
#  './datasets\\monet2photo\\trainA\\00887.jpg',
#  './datasets\\monet2photo\\trainA\\00888.jpg',
#  './datasets\\monet2photo\\trainA\\00889.jpg',
#  './datasets\\monet2photo\\trainA\\00891.jpg',
#  './datasets\\monet2photo\\trainA\\00892.jpg',
#  './datasets\\monet2photo\\trainA\\00893.jpg',
#  './datasets\\monet2photo\\trainA\\00894.jpg',
#  './datasets\\monet2photo\\trainA\\00895.jpg',
#  './datasets\\monet2photo\\trainA\\00896.jpg',
#  './datasets\\monet2photo\\trainA\\00897.jpg',
#  './datasets\\monet2photo\\trainA\\00899.jpg',
#  './datasets\\monet2photo\\trainA\\00901.jpg',
#  './datasets\\monet2photo\\trainA\\00902.jpg',
#  './datasets\\monet2photo\\trainA\\00903.jpg',
#  './datasets\\monet2photo\\trainA\\00904.jpg',
#  './datasets\\monet2photo\\trainA\\00905.jpg',
#  './datasets\\monet2photo\\trainA\\00906.jpg',
#  './datasets\\monet2photo\\trainA\\00907.jpg',
#  './datasets\\monet2photo\\trainA\\00908.jpg',
#  './datasets\\monet2photo\\trainA\\00909.jpg',
#  './datasets\\monet2photo\\trainA\\00911.jpg',
#  './datasets\\monet2photo\\trainA\\00912.jpg',
#  './datasets\\monet2photo\\trainA\\00915.jpg',
#  './datasets\\monet2photo\\trainA\\00916.jpg',
#  './datasets\\monet2photo\\trainA\\00917.jpg',
#  './datasets\\monet2photo\\trainA\\00918.jpg',
#  './datasets\\monet2photo\\trainA\\00919.jpg',
#  './datasets\\monet2photo\\trainA\\00921.jpg',
#  './datasets\\monet2photo\\trainA\\00922.jpg',
#  './datasets\\monet2photo\\trainA\\00923.jpg',
#  './datasets\\monet2photo\\trainA\\00924.jpg',
#  './datasets\\monet2photo\\trainA\\00925.jpg',
#  './datasets\\monet2photo\\trainA\\00926.jpg',
#  './datasets\\monet2photo\\trainA\\00927.jpg',
#  './datasets\\monet2photo\\trainA\\00928.jpg',
#  './datasets\\monet2photo\\trainA\\00929.jpg',
#  './datasets\\monet2photo\\trainA\\00931.jpg',
#  './datasets\\monet2photo\\trainA\\00932.jpg',
#  './datasets\\monet2photo\\trainA\\00933.jpg',
#  './datasets\\monet2photo\\trainA\\00934.jpg',
#  './datasets\\monet2photo\\trainA\\00935.jpg',
#  './datasets\\monet2photo\\trainA\\00936.jpg',
#  './datasets\\monet2photo\\trainA\\00937.jpg',
#  './datasets\\monet2photo\\trainA\\00938.jpg',
#  './datasets\\monet2photo\\trainA\\00939.jpg',
#  './datasets\\monet2photo\\trainA\\00941.jpg',
#  './datasets\\monet2photo\\trainA\\00942.jpg',
#  './datasets\\monet2photo\\trainA\\00943.jpg',
#  './datasets\\monet2photo\\trainA\\00944.jpg',
#  './datasets\\monet2photo\\trainA\\00946.jpg',
#  './datasets\\monet2photo\\trainA\\00947.jpg',
#  './datasets\\monet2photo\\trainA\\00948.jpg',
#  './datasets\\monet2photo\\trainA\\00949.jpg',
#  './datasets\\monet2photo\\trainA\\00951.jpg',
#  './datasets\\monet2photo\\trainA\\00952.jpg',
#  './datasets\\monet2photo\\trainA\\00953.jpg',
#  './datasets\\monet2photo\\trainA\\00954.jpg',
#  './datasets\\monet2photo\\trainA\\00955.jpg',
#  './datasets\\monet2photo\\trainA\\00956.jpg',
#  './datasets\\monet2photo\\trainA\\00957.jpg',
#  './datasets\\monet2photo\\trainA\\00958.jpg',
#  './datasets\\monet2photo\\trainA\\00959.jpg',
#  './datasets\\monet2photo\\trainA\\00961.jpg',
#  './datasets\\monet2photo\\trainA\\00962.jpg',
#  './datasets\\monet2photo\\trainA\\00963.jpg',
#  './datasets\\monet2photo\\trainA\\00964.jpg',
#  './datasets\\monet2photo\\trainA\\00965.jpg',
#  './datasets\\monet2photo\\trainA\\00966.jpg',
#  './datasets\\monet2photo\\trainA\\00967.jpg',
#  './datasets\\monet2photo\\trainA\\00968.jpg',
#  './datasets\\monet2photo\\trainA\\00969.jpg',
#  './datasets\\monet2photo\\trainA\\00971.jpg',
#  './datasets\\monet2photo\\trainA\\00972.jpg',
#  './datasets\\monet2photo\\trainA\\00973.jpg',
#  './datasets\\monet2photo\\trainA\\00974.jpg',
#  './datasets\\monet2photo\\trainA\\00975.jpg',
#  './datasets\\monet2photo\\trainA\\00976.jpg',
#  './datasets\\monet2photo\\trainA\\00977.jpg',
#  './datasets\\monet2photo\\trainA\\00978.jpg',
#  './datasets\\monet2photo\\trainA\\00979.jpg',
#  './datasets\\monet2photo\\trainA\\00981.jpg',
#  './datasets\\monet2photo\\trainA\\00982.jpg',
#  './datasets\\monet2photo\\trainA\\00983.jpg',
#  './datasets\\monet2photo\\trainA\\00984.jpg',
#  './datasets\\monet2photo\\trainA\\00985.jpg',
#  './datasets\\monet2photo\\trainA\\00986.jpg',
#  './datasets\\monet2photo\\trainA\\00987.jpg',
#  './datasets\\monet2photo\\trainA\\00988.jpg',
#  './datasets\\monet2photo\\trainA\\00989.jpg',
#  './datasets\\monet2photo\\trainA\\00991.jpg',
#  './datasets\\monet2photo\\trainA\\00992.jpg',
#  './datasets\\monet2photo\\trainA\\00993.jpg',
#  './datasets\\monet2photo\\trainA\\00994.jpg',
#  './datasets\\monet2photo\\trainA\\00995.jpg',
#  './datasets\\monet2photo\\trainA\\00996.jpg',
#  './datasets\\monet2photo\\trainA\\00997.jpg',
#  './datasets\\monet2photo\\trainA\\00998.jpg',
#  './datasets\\monet2photo\\trainA\\00999.jpg',
#  './datasets\\monet2photo\\trainA\\01001.jpg',
#  './datasets\\monet2photo\\trainA\\01002.jpg',
#  './datasets\\monet2photo\\trainA\\01003.jpg',
#  './datasets\\monet2photo\\trainA\\01004.jpg',
#  './datasets\\monet2photo\\trainA\\01005.jpg',
#  './datasets\\monet2photo\\trainA\\01006.jpg',
#  './datasets\\monet2photo\\trainA\\01008.jpg',
#  './datasets\\monet2photo\\trainA\\01009.jpg',
#  './datasets\\monet2photo\\trainA\\01011.jpg',
#  './datasets\\monet2photo\\trainA\\01013.jpg',
#  './datasets\\monet2photo\\trainA\\01014.jpg',
#  './datasets\\monet2photo\\trainA\\01015.jpg',
#  './datasets\\monet2photo\\trainA\\01016.jpg',
#  './datasets\\monet2photo\\trainA\\01017.jpg',
#  './datasets\\monet2photo\\trainA\\01018.jpg',
#  './datasets\\monet2photo\\trainA\\01019.jpg',
#  './datasets\\monet2photo\\trainA\\01022.jpg',
#  './datasets\\monet2photo\\trainA\\01023.jpg',
#  './datasets\\monet2photo\\trainA\\01024.jpg',
#  './datasets\\monet2photo\\trainA\\01025.jpg',
#  './datasets\\monet2photo\\trainA\\01026.jpg',
#  './datasets\\monet2photo\\trainA\\01027.jpg',
#  './datasets\\monet2photo\\trainA\\01028.jpg',
#  './datasets\\monet2photo\\trainA\\01029.jpg',
#  './datasets\\monet2photo\\trainA\\01031.jpg',
#  './datasets\\monet2photo\\trainA\\01032.jpg',
#  './datasets\\monet2photo\\trainA\\01033.jpg',
#  './datasets\\monet2photo\\trainA\\01034.jpg',
#  './datasets\\monet2photo\\trainA\\01035.jpg',
#  './datasets\\monet2photo\\trainA\\01036.jpg',
#  './datasets\\monet2photo\\trainA\\01037.jpg',
#  './datasets\\monet2photo\\trainA\\01038.jpg',
#  './datasets\\monet2photo\\trainA\\01039.jpg',
#  './datasets\\monet2photo\\trainA\\01041.jpg',
#  './datasets\\monet2photo\\trainA\\01042.jpg',
#  './datasets\\monet2photo\\trainA\\01043.jpg',
#  './datasets\\monet2photo\\trainA\\01044.jpg',
#  './datasets\\monet2photo\\trainA\\01046.jpg',
#  './datasets\\monet2photo\\trainA\\01047.jpg',
#  './datasets\\monet2photo\\trainA\\01048.jpg',
#  './datasets\\monet2photo\\trainA\\01049.jpg',
#  './datasets\\monet2photo\\trainA\\01051.jpg',
#  './datasets\\monet2photo\\trainA\\01052.jpg',
#  './datasets\\monet2photo\\trainA\\01055.jpg',
#  './datasets\\monet2photo\\trainA\\01056.jpg',
#  './datasets\\monet2photo\\trainA\\01057.jpg',
#  './datasets\\monet2photo\\trainA\\01058.jpg',
#  './datasets\\monet2photo\\trainA\\01059.jpg',
#  './datasets\\monet2photo\\trainA\\01061.jpg',
#  './datasets\\monet2photo\\trainA\\01062.jpg',
#  './datasets\\monet2photo\\trainA\\01063.jpg',
#  './datasets\\monet2photo\\trainA\\01064.jpg',
#  './datasets\\monet2photo\\trainA\\01065.jpg',
#  './datasets\\monet2photo\\trainA\\01066.jpg',
#  './datasets\\monet2photo\\trainA\\01067.jpg',
#  './datasets\\monet2photo\\trainA\\01068.jpg',
#  './datasets\\monet2photo\\trainA\\01069.jpg',
#  './datasets\\monet2photo\\trainA\\01071.jpg',
#  './datasets\\monet2photo\\trainA\\01072.jpg',
#  './datasets\\monet2photo\\trainA\\01074.jpg',
#  './datasets\\monet2photo\\trainA\\01075.jpg',
#  './datasets\\monet2photo\\trainA\\01076.jpg',
#  './datasets\\monet2photo\\trainA\\01077.jpg',
#  './datasets\\monet2photo\\trainA\\01078.jpg',
#  './datasets\\monet2photo\\trainA\\01079.jpg',
#  './datasets\\monet2photo\\trainA\\01081.jpg',
#  './datasets\\monet2photo\\trainA\\01082.jpg',
#  './datasets\\monet2photo\\trainA\\01083.jpg',
#  './datasets\\monet2photo\\trainA\\01084.jpg',
#  './datasets\\monet2photo\\trainA\\01091.jpg',
#  './datasets\\monet2photo\\trainA\\01092.jpg',
#  './datasets\\monet2photo\\trainA\\01093.jpg',
#  './datasets\\monet2photo\\trainA\\01094.jpg',
#  './datasets\\monet2photo\\trainA\\01095.jpg',
#  './datasets\\monet2photo\\trainA\\01096.jpg',
#  './datasets\\monet2photo\\trainA\\01097.jpg',
#  './datasets\\monet2photo\\trainA\\01098.jpg',
#  './datasets\\monet2photo\\trainA\\01099.jpg',
#  './datasets\\monet2photo\\trainA\\01101.jpg',
#  './datasets\\monet2photo\\trainA\\01102.jpg',
#  './datasets\\monet2photo\\trainA\\01103.jpg',
#  './datasets\\monet2photo\\trainA\\01104.jpg',
#  './datasets\\monet2photo\\trainA\\01105.jpg',
#  './datasets\\monet2photo\\trainA\\01106.jpg',
#  './datasets\\monet2photo\\trainA\\01107.jpg',
#  './datasets\\monet2photo\\trainA\\01108.jpg',
#  './datasets\\monet2photo\\trainA\\01109.jpg',
#  './datasets\\monet2photo\\trainA\\01111.jpg',
#  './datasets\\monet2photo\\trainA\\01112.jpg',
#  './datasets\\monet2photo\\trainA\\01113.jpg',
#  './datasets\\monet2photo\\trainA\\01114.jpg',
#  './datasets\\monet2photo\\trainA\\01115.jpg',
#  './datasets\\monet2photo\\trainA\\01116.jpg',
#  './datasets\\monet2photo\\trainA\\01117.jpg',
#  './datasets\\monet2photo\\trainA\\01118.jpg',
#  './datasets\\monet2photo\\trainA\\01119.jpg',
#  './datasets\\monet2photo\\trainA\\01121.jpg',
#  './datasets\\monet2photo\\trainA\\01122.jpg',
#  './datasets\\monet2photo\\trainA\\01123.jpg',
#  './datasets\\monet2photo\\trainA\\01124.jpg',
#  './datasets\\monet2photo\\trainA\\01125.jpg',
#  './datasets\\monet2photo\\trainA\\01126.jpg',
#  './datasets\\monet2photo\\trainA\\01127.jpg',
#  './datasets\\monet2photo\\trainA\\01128.jpg',
#  './datasets\\monet2photo\\trainA\\01129.jpg',
#  './datasets\\monet2photo\\trainA\\01131.jpg',
#  './datasets\\monet2photo\\trainA\\01132.jpg',
#  './datasets\\monet2photo\\trainA\\01133.jpg',
#  './datasets\\monet2photo\\trainA\\01134.jpg',
#  './datasets\\monet2photo\\trainA\\01135.jpg',
#  './datasets\\monet2photo\\trainA\\01136.jpg',
#  './datasets\\monet2photo\\trainA\\01137.jpg',
#  './datasets\\monet2photo\\trainA\\01138.jpg',
#  './datasets\\monet2photo\\trainA\\01139.jpg',
#  './datasets\\monet2photo\\trainA\\01141.jpg',
#  './datasets\\monet2photo\\trainA\\01142.jpg',
#  './datasets\\monet2photo\\trainA\\01143.jpg',
#  './datasets\\monet2photo\\trainA\\01144.jpg',
#  './datasets\\monet2photo\\trainA\\01145.jpg',
#  './datasets\\monet2photo\\trainA\\01146.jpg',
#  './datasets\\monet2photo\\trainA\\01147.jpg',
#  './datasets\\monet2photo\\trainA\\01148.jpg',
#  './datasets\\monet2photo\\trainA\\01149.jpg',
#  './datasets\\monet2photo\\trainA\\01151.jpg',
#  './datasets\\monet2photo\\trainA\\01152.jpg',
#  './datasets\\monet2photo\\trainA\\01153.jpg',
#  './datasets\\monet2photo\\trainA\\01154.jpg',
#  './datasets\\monet2photo\\trainA\\01155.jpg',
#  './datasets\\monet2photo\\trainA\\01156.jpg',
#  './datasets\\monet2photo\\trainA\\01157.jpg',
#  './datasets\\monet2photo\\trainA\\01158.jpg',
#  './datasets\\monet2photo\\trainA\\01159.jpg',
#  './datasets\\monet2photo\\trainA\\01161.jpg',
#  './datasets\\monet2photo\\trainA\\01162.jpg',
#  './datasets\\monet2photo\\trainA\\01163.jpg',
#  './datasets\\monet2photo\\trainA\\01164.jpg',
#  './datasets\\monet2photo\\trainA\\01165.jpg',
#  './datasets\\monet2photo\\trainA\\01166.jpg',
#  './datasets\\monet2photo\\trainA\\01167.jpg',
#  './datasets\\monet2photo\\trainA\\01168.jpg',
#  './datasets\\monet2photo\\trainA\\01169.jpg',
#  './datasets\\monet2photo\\trainA\\01171.jpg',
#  './datasets\\monet2photo\\trainA\\01172.jpg',
#  './datasets\\monet2photo\\trainA\\01173.jpg',
#  './datasets\\monet2photo\\trainA\\01174.jpg',
#  './datasets\\monet2photo\\trainA\\01175.jpg',
#  './datasets\\monet2photo\\trainA\\01176.jpg',
#  './datasets\\monet2photo\\trainA\\01177.jpg',
#  './datasets\\monet2photo\\trainA\\01178.jpg',
#  './datasets\\monet2photo\\trainA\\01179.jpg',
#  './datasets\\monet2photo\\trainA\\01181.jpg',
#  './datasets\\monet2photo\\trainA\\01182.jpg',
#  './datasets\\monet2photo\\trainA\\01183.jpg',
#  './datasets\\monet2photo\\trainA\\01184.jpg',
#  './datasets\\monet2photo\\trainA\\01185.jpg',
#  './datasets\\monet2photo\\trainA\\01186.jpg',
#  './datasets\\monet2photo\\trainA\\01187.jpg',
#  './datasets\\monet2photo\\trainA\\01188.jpg',
#  './datasets\\monet2photo\\trainA\\01189.jpg',
#  './datasets\\monet2photo\\trainA\\01191.jpg',
#  './datasets\\monet2photo\\trainA\\01192.jpg',
#  './datasets\\monet2photo\\trainA\\01193.jpg',
#  './datasets\\monet2photo\\trainA\\01194.jpg',
#  './datasets\\monet2photo\\trainA\\01195.jpg',
#  './datasets\\monet2photo\\trainA\\01196.jpg',
#  './datasets\\monet2photo\\trainA\\01197.jpg',
#  './datasets\\monet2photo\\trainA\\01198.jpg',
#  './datasets\\monet2photo\\trainA\\01199.jpg',
#  './datasets\\monet2photo\\trainA\\01201.jpg',
#  './datasets\\monet2photo\\trainA\\01202.jpg',
#  './datasets\\monet2photo\\trainA\\01203.jpg',
#  './datasets\\monet2photo\\trainA\\01204.jpg',
#  './datasets\\monet2photo\\trainA\\01205.jpg',
#  './datasets\\monet2photo\\trainA\\01206.jpg',
#  './datasets\\monet2photo\\trainA\\01207.jpg',
#  './datasets\\monet2photo\\trainA\\01208.jpg',
#  './datasets\\monet2photo\\trainA\\01209.jpg',
#  './datasets\\monet2photo\\trainA\\01211.jpg',
#  './datasets\\monet2photo\\trainA\\01212.jpg',
#  './datasets\\monet2photo\\trainA\\01213.jpg',
#  './datasets\\monet2photo\\trainA\\01214.jpg',
#  './datasets\\monet2photo\\trainA\\01215.jpg',
#  './datasets\\monet2photo\\trainA\\01216.jpg',
#  './datasets\\monet2photo\\trainA\\01217.jpg',
#  './datasets\\monet2photo\\trainA\\01218.jpg',
#  './datasets\\monet2photo\\trainA\\01219.jpg',
#  './datasets\\monet2photo\\trainA\\01221.jpg',
#  './datasets\\monet2photo\\trainA\\01222.jpg',
#  './datasets\\monet2photo\\trainA\\01223.jpg',
#  './datasets\\monet2photo\\trainA\\01224.jpg',
#  './datasets\\monet2photo\\trainA\\01225.jpg',
#  './datasets\\monet2photo\\trainA\\01226.jpg',
#  './datasets\\monet2photo\\trainA\\01227.jpg',
#  './datasets\\monet2photo\\trainA\\01228.jpg',
#  './datasets\\monet2photo\\trainA\\01229.jpg',
#  './datasets\\monet2photo\\trainA\\01231.jpg',
#  './datasets\\monet2photo\\trainA\\01232.jpg',
#  './datasets\\monet2photo\\trainA\\01233.jpg',
#  './datasets\\monet2photo\\trainA\\01234.jpg',
#  './datasets\\monet2photo\\trainA\\01235.jpg',
#  './datasets\\monet2photo\\trainA\\01236.jpg',
#  './datasets\\monet2photo\\trainA\\01237.jpg',
#  './datasets\\monet2photo\\trainA\\01238.jpg',
#  './datasets\\monet2photo\\trainA\\01239.jpg',
#  './datasets\\monet2photo\\trainA\\01241.jpg',
#  './datasets\\monet2photo\\trainA\\01242.jpg',
#  './datasets\\monet2photo\\trainA\\01243.jpg',
#  './datasets\\monet2photo\\trainA\\01244.jpg',
#  './datasets\\monet2photo\\trainA\\01246.jpg',
#  './datasets\\monet2photo\\trainA\\01247.jpg',
#  './datasets\\monet2photo\\trainA\\01248.jpg',
#  './datasets\\monet2photo\\trainA\\01249.jpg',
#  './datasets\\monet2photo\\trainA\\01251.jpg',
#  './datasets\\monet2photo\\trainA\\01252.jpg',
#  './datasets\\monet2photo\\trainA\\01253.jpg',
#  './datasets\\monet2photo\\trainA\\01254.jpg',
#  './datasets\\monet2photo\\trainA\\01255.jpg',
#  './datasets\\monet2photo\\trainA\\01256.jpg',
#  ...]

# %%
utiles = 11

import random
import time
import datetime
import sys

from torch.autograd import Variable
import torch
from visdom import Visdom
import numpy as np

def tensor2image(tensor):
    image = 127.5*(tensor[0].cpu().float().numpy() + 1.0)
    if image.shape[0] == 1:
        image = np.tile(image, (3,1,1))
    return image.astype(np.uint8)

class Logger():
    def __init__(self, n_epochs, batches_epoch):
        self.viz = Visdom()
        self.n_epochs = n_epochs
        self.batches_epoch = batches_epoch
        self.epoch = 1
        self.batch = 1
        self.prev_time = time.time()
        self.mean_period = 0
        self.losses = {}
        self.loss_windows = {}
        self.image_windows = {}


    def log(self, losses=None, images=None):
        self.mean_period += (time.time() - self.prev_time)
        self.prev_time = time.time()

        sys.stdout.write('\rEpoch %03d/%03d [%04d/%04d] -- ' % (self.epoch, self.n_epochs, self.batch, self.batches_epoch))

        for i, loss_name in enumerate(losses.keys()):
            if loss_name not in self.losses:
                self.losses[loss_name] = losses[loss_name].data[0]
            else:
                self.losses[loss_name] += losses[loss_name].data[0]

            if (i+1) == len(losses.keys()):
                sys.stdout.write('%s: %.4f -- ' % (loss_name, self.losses[loss_name]/self.batch))
            else:
                sys.stdout.write('%s: %.4f | ' % (loss_name, self.losses[loss_name]/self.batch))

        batches_done = self.batches_epoch*(self.epoch - 1) + self.batch
        batches_left = self.batches_epoch*(self.n_epochs - self.epoch) + self.batches_epoch - self.batch
        sys.stdout.write('ETA: %s' % (datetime.timedelta(seconds=batches_left*self.mean_period/batches_done)))

        # Draw images
        for image_name, tensor in images.items():
            if image_name not in self.image_windows:
                self.image_windows[image_name] = self.viz.image(tensor2image(tensor.data), opts={'title':image_name})
            else:
                self.viz.image(tensor2image(tensor.data), win=self.image_windows[image_name], opts={'title':image_name})

        # End of epoch
        if (self.batch % self.batches_epoch) == 0:
            # Plot losses
            for loss_name, loss in self.losses.items():
                if loss_name not in self.loss_windows:
                    self.loss_windows[loss_name] = self.viz.line(X=np.array([self.epoch]), Y=np.array([loss/self.batch]),
                                                                    opts={'xlabel': 'epochs', 'ylabel': loss_name, 'title': loss_name})
                else:
                    self.viz.line(X=np.array([self.epoch]), Y=np.array([loss/self.batch]), win=self.loss_windows[loss_name], update='append')
                # Reset losses for next epoch
                self.losses[loss_name] = 0.0

            self.epoch += 1
            self.batch = 1
            sys.stdout.write('\n')
        else:
            self.batch += 1



class ReplayBuffer():
    def __init__(self, max_size=50):
        assert (max_size > 0), 'Empty buffer or trying to create a black hole. Be careful.'
        self.max_size = max_size
        self.data = []

    def push_and_pop(self, data):
        to_return = []
        for element in data.data:
            element = torch.unsqueeze(element, 0)
            if len(self.data) < self.max_size:
                self.data.append(element)
                to_return.append(element)
            else:
                if random.uniform(0,1) > 0.5:
                    i = random.randint(0, self.max_size-1)
                    to_return.append(self.data[i].clone())
                    self.data[i] = element
                else:
                    to_return.append(element)
        return Variable(torch.cat(to_return))

class LambdaLR():
    def __init__(self, n_epochs, offset, decay_start_epoch):
        assert ((n_epochs - decay_start_epoch) > 0), "Decay must start before the training session ends!"
        self.n_epochs = n_epochs
        self.offset = offset
        self.decay_start_epoch = decay_start_epoch

    def step(self, epoch):
        return 1.0 - max(0, epoch + self.offset - self.decay_start_epoch)/(self.n_epochs - self.decay_start_epoch)

def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        torch.nn.init.normal(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        torch.nn.init.normal(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant(m.bias.data, 0.0)

# %%
with open('epoch.txt', 'w') as f:
    epoch =
